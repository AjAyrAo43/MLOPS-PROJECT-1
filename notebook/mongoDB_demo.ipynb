# %%
import pandas as pd

# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://ajayrao4376_db_user:<db_password>@cluster0.q2wcm4e.mongodb.net/?appName=Cluster0"

# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github.

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 client = pymongo.MongoClient(CONNECTION_URL)
#       2 data_base = client[DB_NAME]
#       3 collection = data_base[COLLECTION_NAME]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymongo\synchronous\mongo_client.py:891, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     888     self._init_background()
#     890 if _IS_SYNC and connect:
# --> 891     self._get_topology()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymongo\synchronous\mongo_client.py:1758, in MongoClient._get_topology(self)
#    1756 if not self._opened:
#    1757     if self._resolve_srv_info["is_srv"]:
# -> 1758         self._resolve_srv()
#    1759         self._init_background()
#    1760     self._topology.open()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymongo\synchronous\mongo_client.py:956, in MongoClient._resolve_srv(self)
#     954 username = opts.get("username", self._resolve_srv_info["username"])
#     955 password = opts.get("password", self._resolve_srv_info["password"])
# --> 956 self._options = ClientOptions(
#     957     username, password, self._resolve_srv_info["dbase"], opts, _IS_SYNC
#     958 )
#     960 self._init_based_on_options(seeds, srv_max_hosts, srv_service_name)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymongo\client_options.py:222, in ClientOptions.__init__(self, username, password, database, options, is_sync)
#     217 # self.__server_selection_timeout is in seconds. Must use full name for
#     218 # common.SERVER_SELECTION_TIMEOUT because it is set directly by tests.
#     219 self.__server_selection_timeout = options.get(
#     220     "serverselectiontimeoutms", common.SERVER_SELECTION_TIMEOUT
#     221 )
# --> 222 self.__pool_options = _parse_pool_options(username, password, database, options, is_sync)
#     223 self.__read_preference = _parse_read_preference(options)
#     224 self.__replica_set_name = options.get("replicaset")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymongo\client_options.py:173, in _parse_pool_options(username, password, database, options, is_sync)
#     169 server_api = options.get("server_api")
#     170 compression_settings = CompressionSettings(
#     171     options.get("compressors", []), options.get("zlibcompressionlevel", -1)
#     172 )
# --> 173 ssl_context, tls_allow_invalid_hostnames = _parse_ssl_options(options, is_sync)
#     174 load_balanced = options.get("loadbalanced")
#     175 max_connecting = options.get("maxconnecting", common.MAX_CONNECTING)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymongo\client_options.py:135, in _parse_ssl_options(options, is_sync)
#     128         raise ConfigurationError(
#     129             "TLS has not been enabled but the "
#     130             "following tls parameters have been set: "
#     131             "%s. Please set `tls=True` or remove." % ", ".join(enabled_tls_opts)
#     132         )
#     134 if use_tls:
# --> 135     ctx = get_ssl_context(
#     136         certfile,
#     137         passphrase,
#     138         ca_certs,
#     139         crlfile,
#     140         allow_invalid_certificates,
#     141         allow_invalid_hostnames,
#     142         disable_ocsp_endpoint_check,
#     143         is_sync,
#     144     )
#     145     return ctx, allow_invalid_hostnames
#     146 return None, allow_invalid_hostnames
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymongo\ssl_support.py:129, in get_ssl_context(certfile, passphrase, ca_certs, crlfile, allow_invalid_certificates, allow_invalid_hostnames, disable_ocsp_endpoint_check, is_sync)
#     127     ctx.load_verify_locations(ca_certs)
#     128 elif verify_mode != CERT_NONE:
# --> 129     ctx.load_default_certs()
#     130 ctx.verify_mode = verify_mode
#     131 return ctx
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymongo\pyopenssl_context.py:365, in SSLContext.load_default_certs(self)
#     363 elif _sys.platform == "darwin":
#     364     self._load_certifi()
# --> 365 self._ctx.set_default_verify_paths()
#
# File c:\Users\Ajayr\anaconda3\Lib\site-packages\OpenSSL\SSL.py:1034, in Context.set_default_verify_paths(self)
#    1028 _openssl_assert(set_result == 1)
#    1029 # After attempting to set default_verify_paths we need to know whether
#    1030 # to go down the fallback path.
#    1031 # First we'll check to see if any env vars have been set. If so,
#    1032 # we won't try to do anything else because the user has set the path
#    1033 # themselves.
# -> 1034 dir_env_var = _ffi.string(_lib.X509_get_default_cert_dir_env()).decode(
#    1035     "ascii"
#    1036 )
#    1037 file_env_var = _ffi.string(
#    1038     _lib.X509_get_default_cert_file_env()
#    1039 ).decode("ascii")
#    1040 if not self._check_env_vars_set(dir_env_var, file_env_var):
#
# AttributeError: module 'lib' has no attribute 'X509_get_default_cert_dir_env'

# %%
# !pip install pymongo --pre
# !pip install cryptography --pre
# Out:
# Requirement already satisfied: pymongo in c:\users\ajayr\appdata\roaming\python\python313\site-packages (4.16.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in c:\users\ajayr\appdata\roaming\python\python313\site-packages (from pymongo) (2.8.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: cryptography in c:\users\ajayr\appdata\roaming\python\python313\site-packages (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\ajayr\appdata\roaming\python\python313\site-packages (from cryptography) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\ajayr\appdata\roaming\python\python313\site-packages (from cffi>=2.0.0->cryptography) (2.23)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
